# %%
api_key = "AIzaSyDLXGoELUF8Omi9Q2wtAONvvN4S8gfkcL0"
from apiclient.discovery import build
youtube = build('youtube','v3',developerKey=api_key)

# %%
res = youtube.search().list(q='mr beast',part='snippet',type='channel',maxResults=50).execute()

# %%
# for i in res['items']:
#     print(i['snippet']['title'],"https://www.youtube.com/channel/"+i['snippet']['channelId'])

# %%
from datetime import datetime

# %%
start_time = datetime(year=2005,month=1,day=1).strftime('%Y-%m-%dT%H:%M:%SZ')
end_time = datetime(year=2018,month=1,day=1).strftime('%Y-%m-%dT%H:%M:%SZ')
start_time
# Out:
# '2005-01-01T00:00:00Z'

# %%
res = youtube.search().list(q='covid19',
                            part='snippet',
                            type='video',
                            maxResults=50,
                            publishedAfter=start_time,
                            publishedBefore=end_time).execute()

# %%
for i in res['items']:
    print(i['snippet']['publishedAt'],i['snippet']['title'])

# %%
res = youtube.channels().list(id="UC2XFVlawVToInLFwh8xQntQ",part='contentDetails').execute()
res

# %%
res1 = youtube.playlistItems().list(playlistId='UU2XFVlawVToInLFwh8xQntQ',part='snippet',maxResults=40).execute()
len(res1['items'])

# %%
def get_channel_videos(channel_id):
    res = youtube.channels().list(id=channel_id,
                                 part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    videos = []
    next_page_token = None
    while 1:
        res = youtube.playlistItems().list(playlistId=playlist_id,
                                          part='snippet',
                                          maxResults=50,
                                          pageToken=next_page_token).execute()
        videos += res['items']
        next_page_token = res.get('nextPageToken')
        if next_page_token is None:
            break
    return videos

# %%
vids = get_channel_videos('UCq-Fj5jknLsUf-MWSy4_brA')

# %%
res = youtube.videos().list(id=vids[0]['snippet']['resourceId']['videoId'],
                           part='statistics').execute()
video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'],vids))

# %%
def get_videos_stats(video_ids):
    stats = []
    for i in range(0,len(video_ids),50):
        res = youtube.videos().list(id=",".join(video_ids[i:i+50]),
                                   part='statistics').execute()
        stats+=res['items']
    return stats
stats = get_videos_stats(video_ids)

# %%
p = []
for i in stats:
    p.append((i['id'],i['statistics']['viewCount']))
stats[0]

# %%
p = []
hidden = []
for i in stats:
    try:
        p.append((i['id'],i['statistics']['viewCount'],i['statistics']['dislikeCount']))
    except:
        hidden.append("https://www.youtube.com/watch?v="+i['id'])
moody_hidden = []
k = ""
for i in moody_stats:
    try:
        k = (i['id'],i['statistics']['viewCount'],i['statistics']['dislikeCount'])
    except:
        moody_hidden.append("https://www.youtube.com/watch?v="+i['id'])

# %%
def get_channel_videos(channel_id):
    res = youtube.channels().list(id=channel_id,
                                 part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    videos = []
    next_page_token = None
    while 1:
        res = youtube.playlistItems().list(playlistId=playlist_id,
                                          part='snippet',
                                          maxResults=50,
                                          pageToken=next_page_token).execute()
        videos += res['items']
        next_page_token = res.get('nextPageToken')
        if next_page_token is None:
            break
    return videos

def get_videos_stats(video_ids):
    stats = []
    for i in range(0,len(video_ids),50):
        res = youtube.videos().list(id=",".join(video_ids[i:i+50]),
                                   part='statistics').execute()
        stats+=res['items']
    return stats

dani_vids = get_channel_videos('UC7wXt18f2iA3EDXeqAVuKng')
dani_video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'],dani_vids))
dani_stats = get_videos_stats(dani_video_ids)

dani_hidden = []
k = ""
for i in dani_stats:
    try:
        k = (i['id'],i['statistics']['viewCount'],i['statistics']['dislikeCount'])
    except:
        dani_hidden.append("https://www.youtube.com/watch?v="+i['id'])
        
print(dani_hidden)
# Out:
# ['https://www.youtube.com/watch?v=vrugPfGkGoU', 'https://www.youtube.com/watch?v=fREjC5MA3WU', 'https://www.youtube.com/watch?v=_1ExFcwNaOU', 'https://www.youtube.com/watch?v=MqrJgSvrrRM', 'https://www.youtube.com/watch?v=Lww4nfcx8n0', 'https://www.youtube.com/watch?v=bXmCAyxquaU', 'https://www.youtube.com/watch?v=g1oNgOGToF8', 'https://www.youtube.com/watch?v=u1syBXt3l7U', 'https://www.youtube.com/watch?v=T3wpNsPS9Vg', 'https://www.youtube.com/watch?v=Zjb3RPrcfNo', 'https://www.youtube.com/watch?v=MuZ-mmHg5Jk', 'https://www.youtube.com/watch?v=h-ocFLhShv4', 'https://www.youtube.com/watch?v=XkvYtdIdDXA', 'https://www.youtube.com/watch?v=hv8wMEkC5EY', 'https://www.youtube.com/watch?v=AHw5owB1-2o', 'https://www.youtube.com/watch?v=On0bFoVhYkU', 'https://www.youtube.com/watch?v=myXECt0w1EY', 'https://www.youtube.com/watch?v=oxmVy-6ld7c', 'https://www.youtube.com/watch?v=C8m2BQCOANc', 'https://www.youtube.com/watch?v=eo1obswzfEw', 'https://www.youtube.com/watch?v=ZSqy0Alz55I', 'https://www.youtube.com/watch?v=KEkIIPEUqfQ', 'https://www.youtube.com/watch?v=G1UzrK69Adk', 'https://www.youtube.com/watch?v=ziiSmJrON5k', 'https://www.youtube.com/watch?v=E94AE0sAePM', 'https://www.youtube.com/watch?v=TzhrrM9SVMM', 'https://www.youtube.com/watch?v=gsNluZliCAc', 'https://www.youtube.com/watch?v=9OD2sYw_Rpg', 'https://www.youtube.com/watch?v=ynQ8g_q6egg', 'https://www.youtube.com/watch?v=-vR8ll6MjP0', 'https://www.youtube.com/watch?v=S-htfwOFMgg', 'https://www.youtube.com/watch?v=e4rm4RyhV_k', 'https://www.youtube.com/watch?v=wpHeioDZ7GA', 'https://www.youtube.com/watch?v=V5NNaws3ECg', 'https://www.youtube.com/watch?v=mR_nnHODKPE', 'https://www.youtube.com/watch?v=WCL-RKWcDiE', 'https://www.youtube.com/watch?v=nY86cqrIPq8', 'https://www.youtube.com/watch?v=eZLg7WGE0Xo', 'https://www.youtube.com/watch?v=SGwZ_tTP1so', 'https://www.youtube.com/watch?v=S4yv3pQ92XA', 'https://www.youtube.com/watch?v=uLYJa3dlNcg', 'https://www.youtube.com/watch?v=CnR_cUjk02A', 'https://www.youtube.com/watch?v=2LTUoOFHaJI', 'https://www.youtube.com/watch?v=c3Eg4IvpITA', 'https://www.youtube.com/watch?v=CeIaRTN2ttI', 'https://www.youtube.com/watch?v=aKEzv-y13NI', 'https://www.youtube.com/watch?v=6K3QiSGB38c', 'https://www.youtube.com/watch?v=DpCineJ-GTs', 'https://www.youtube.com/watch?v=uwz979ib-KM', 'https://www.youtube.com/watch?v=EZ5r_7Gmkq8', 'https://www.youtube.com/watch?v=iIdlEOGnSEU', 'https://www.youtube.com/watch?v=3LCQdKcPfAk', 'https://www.youtube.com/watch?v=FOrw1SZ-6og', 'https://www.youtube.com/watch?v=yjnBgr5XLZ0', 'https://www.youtube.com/watch?v=0IYiIFc-7So', 'https://www.youtube.com/watch?v=HvMxyIZWsQE', 'https://www.youtube.com/watch?v=5wKSd5OQWQ4', 'https://www.youtube.com/watch?v=nYlFOfeRW1g', 'https://www.youtube.com/watch?v=6sZP5sR-lLs', 'https://www.youtube.com/watch?v=-LdTQdd22Hw', 'https://www.youtube.com/watch?v=xbkFF8eaWx0', 'https://www.youtube.com/watch?v=jxY7i8925NA', 'https://www.youtube.com/watch?v=UPsn1GenWi4', 'https://www.youtube.com/watch?v=g0tfe_XtHvo', 'https://www.youtube.com/watch?v=0E5tjc4EoTU', 'https://www.youtube.com/watch?v=J1pmMk-edLQ', 'https://www.youtube.com/watch?v=GEXyW59QRBQ', 'https://www.youtube.com/watch?v=cUW4jeh9yx0', 'https://www.youtube.com/watch?v=bYcZrBPgWVE', 'https://www.youtube.com/watch?v=qm-d1qHmvA8', 'https://www.youtube.com/watch?v=0DXj4If4IhI', 'https://www.youtube.com/watch?v=mcVr59WH_dY', 'https://www.youtube.com/watch?v=7EYKnZ5_zWg', 'https://www.youtube.com/watch?v=8RIy2tfrn9c', 'https://www.youtube.com/watch?v=9W_AxeqybAU', 'https://www.youtube.com/watch?v=PNkiwrMHux8', 'https://www.youtube.com/watch?v=YQCY_fswQsc', 'https://www.youtube.com/watch?v=Pb_IRbU_6RQ', 'https://www.youtube.com/watch?v=4zlvJrsRMwY', 'https://www.youtube.com/watch?v=_Sj4x2bt6hs', 'https://www.youtube.com/watch?v=8xwNhZYTZOU', 'https://www.youtube.com/watch?v=g18Kgp_KOwc', 'https://www.youtube.com/watch?v=QPdVbRDMG9c', 'https://www.youtube.com/watch?v=J4mPuZ8PNcg', 'https://www.youtube.com/watch?v=mjn3jpyhC_A', 'htt ...

# %%
# like_to_dislike = sorted(stats,key=lambda x:(int(x['statistics']['likeCount'])),reverse=True)

# %%
z = like_to_dislike[0]['statistics']
t = like_to_dislike[-1]['statistics']
print(int(z['likeCount'])/int(z['dislikeCount']))
print(int(t['likeCount'])/int(t['dislikeCount']))

# %%
mx = [0,""]
mn =[1000000,""]
for i in dani_stats:
    p = i['statistics']
    try:
        if int(mx[0])<int(p['dislikeCount']):
            mx= [p['dislikeCount'],i['id']]
        if int(mn[0])>int(p['dislikeCount']):
            mn = [p['dislikeCount'],i['id']]
    except:
        pass

# %%
z = []
for i in dani_stats:
    z.append(i['id'])

# %%
# for i in z:

# %%
z = []
for i in range(100):
    z.append(dani_stats[i]['id'])

# %%
z
# Out:
# ['vrugPfGkGoU',
#  'fREjC5MA3WU',
#  '_1ExFcwNaOU',
#  'MqrJgSvrrRM',
#  'Lww4nfcx8n0',
#  'bXmCAyxquaU',
#  'g1oNgOGToF8',
#  'u1syBXt3l7U',
#  'T3wpNsPS9Vg',
#  'Zjb3RPrcfNo',
#  'MuZ-mmHg5Jk',
#  'h-ocFLhShv4',
#  'XkvYtdIdDXA',
#  'hv8wMEkC5EY',
#  'AHw5owB1-2o',
#  'On0bFoVhYkU',
#  'myXECt0w1EY',
#  'oxmVy-6ld7c',
#  'C8m2BQCOANc',
#  'eo1obswzfEw',
#  'ZSqy0Alz55I',
#  'KEkIIPEUqfQ',
#  'G1UzrK69Adk',
#  'ziiSmJrON5k',
#  'E94AE0sAePM',
#  'TzhrrM9SVMM',
#  'gsNluZliCAc',
#  '9OD2sYw_Rpg',
#  'ynQ8g_q6egg',
#  '-vR8ll6MjP0',
#  'S-htfwOFMgg',
#  'e4rm4RyhV_k',
#  'wpHeioDZ7GA',
#  'V5NNaws3ECg',
#  'mR_nnHODKPE',
#  'WCL-RKWcDiE',
#  'nY86cqrIPq8',
#  'eZLg7WGE0Xo',
#  'SGwZ_tTP1so',
#  'S4yv3pQ92XA',
#  'uLYJa3dlNcg',
#  'CnR_cUjk02A',
#  '2LTUoOFHaJI',
#  'c3Eg4IvpITA',
#  'CeIaRTN2ttI',
#  'aKEzv-y13NI',
#  '6K3QiSGB38c',
#  'DpCineJ-GTs',
#  'uwz979ib-KM',
#  'EZ5r_7Gmkq8',
#  'iIdlEOGnSEU',
#  '3LCQdKcPfAk',
#  'FOrw1SZ-6og',
#  'yjnBgr5XLZ0',
#  '0IYiIFc-7So',
#  'HvMxyIZWsQE',
#  '5wKSd5OQWQ4',
#  'nYlFOfeRW1g',
#  '6sZP5sR-lLs',
#  '-LdTQdd22Hw',
#  'xbkFF8eaWx0',
#  'jxY7i8925NA',
#  'UPsn1GenWi4',
#  'g0tfe_XtHvo',
#  '0E5tjc4EoTU',
#  'J1pmMk-edLQ',
#  'GEXyW59QRBQ',
#  'cUW4jeh9yx0',
#  'bYcZrBPgWVE',
#  'qm-d1qHmvA8',
#  '0DXj4If4IhI',
#  'mcVr59WH_dY',
#  '7EYKnZ5_zWg',
#  '8RIy2tfrn9c',
#  '9W_AxeqybAU',
#  'PNkiwrMHux8',
#  'YQCY_fswQsc',
#  'Pb_IRbU_6RQ',
#  '4zlvJrsRMwY',
#  '_Sj4x2bt6hs',
#  '8xwNhZYTZOU',
#  'g18Kgp_KOwc',
#  'QPdVbRDMG9c',
#  'J4mPuZ8PNcg',
#  'mjn3jpyhC_A',
#  'cEg-WA812r0',
#  'cBSs1v0tcSU',
#  'TchRuRa0G2c',
#  'Jj3Ugul2gdk',
#  'wDToZptG1LI',
#  'dTfyH1XJpDY',
#  'iuv9UD7oZDk',
#  'UILWHyr4PPE',
#  'Kc4R-nFdwXA',
#  'CHcDz_XjFcE',
#  'whLwdyor_fg',
#  'SwBxhoBc4yw',
#  'SN36-Hp8jME',
#  'He2g739uoT4',
#  'o_OHdc-nQVo']
