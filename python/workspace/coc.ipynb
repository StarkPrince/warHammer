# %%
import pandas as pd

# %%
df = pd.read_csv("td.csv")
df.tail()
# Out:
#        duration                                     resource_title  \
# 1595  3600000.0        Masters of Sex: Fight (Season 2, Episode 3)
# 1596  2520000.0  DC's Legends of Tomorrow: WVRDR_ERROR_100 Oest...
# 1597  9420000.0                                    Eternals (2021)
# 1598  8700000.0                                Sooryavanshi (2021)
# 1599  9720000.0             Aravindha Sametha Veera Raghava (2018)
#
#                                            resource_url      author  \
# 1595  https://trakt.tv/search/trakt/958127?id_type=e...  a2b09k4oqt
# 1596  https://trakt.tv/search/trakt/5362384?id_type=...  a2b09k4oqt
# 1597  https://trakt.tv/search/trakt/372798?id_type=m...  a2b09k4oqt
# 1598  https://trakt.tv/search/trakt/438503?id_type=m...  a2b09k4oqt
# 1599  https://trakt.tv/search/trakt/386177?id_type=m...  a2b09k4oqt
#
#              @id                                                tag  \
# 1595  in9sfveuie                                      episode;drama
# ...

# %%
#how to separate a dataframe on based on a column
grouped = df.groupby(df.resource_url)
# Out:
# https://trakt.tv/search/trakt/100325?id_type=movie
# https://trakt.tv/search/trakt/101517?id_type=movie
# https://trakt.tv/search/trakt/102156?id_type=movie
# https://trakt.tv/search/trakt/102162?id_type=movie
# https://trakt.tv/search/trakt/1032?id_type=movie
# https://trakt.tv/search/trakt/1033?id_type=movie
# https://trakt.tv/search/trakt/103449?id_type=movie
# https://trakt.tv/search/trakt/1048?id_type=movie
# https://trakt.tv/search/trakt/106450?id_type=movie
# https://trakt.tv/search/trakt/106505?id_type=movie
# https://trakt.tv/search/trakt/106667?id_type=movie
# https://trakt.tv/search/trakt/10679?id_type=movie
# https://trakt.tv/search/trakt/1067?id_type=movie
# https://trakt.tv/search/trakt/10693?id_type=movie
# https://trakt.tv/search/trakt/107556?id_type=movie
# https://trakt.tv/search/trakt/10803?id_type=movie
# https://trakt.tv/search/trakt/10?id_type=movie
# https://trakt.tv/search/trakt/110398?id_type=movie
# https://trakt.tv/search/trakt/11164?id_type=movie
# ...

# %%
gd.head()
# Out:
#        duration                                     resource.title  \
# 0     9060000.0                           Wonder Woman 1984 (2020)
# 1     6480000.0                                    Deadpool (2016)
# 2     6900000.0                              Doctor Strange (2016)
# 3     8880000.0                                   Inception (2010)
# 4     8580000.0                                The Avengers (2012)
# ...         ...                                                ...
# 1595  3600000.0        Masters of Sex: Fight (Season 2, Episode 3)
# 1596  2520000.0  DC's Legends of Tomorrow: WVRDR_ERROR_100 Oest...
# 1597  9420000.0                                    Eternals (2021)
# 1598  8700000.0                                Sooryavanshi (2021)
# 1599  9720000.0             Aravindha Sametha Veera Raghava (2018)
#
#                                            resource.url      author  \
# 0     https://trakt.tv/search/trakt/311212?id_type=m...  a2b09k4oqt
# ...
